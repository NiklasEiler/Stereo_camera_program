# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from collections import Counter

# %%
csv_file_path = 'my_dataframe1.csv'


data = pd.read_csv(csv_file_path)
data
# Out:
#                0         1         2             3
# 0            NaN       NaN       NaN           NaN
# 1            NaN       NaN       NaN           NaN
# 2            NaN       NaN       NaN           NaN
# 3            NaN       NaN       NaN           NaN
# 4            NaN       NaN       NaN           NaN
# ...          ...       ...       ...           ...
# 307195  0.715680  0.543282  1.224697  5.808325e-39
# 307196  0.717948  0.543282  1.224697  5.900520e-39
# 307197  0.720217  0.543282  1.224697  5.623933e-39
# 307198  0.722485  0.543282  1.224697  5.716129e-39
# 307199  0.724753  0.543282  1.224697  5.531738e-39
#
# [307200 rows x 4 columns]

# %%
data=data.dropna()
data=data.values
data
# Out:
# array([[ 3.94295871e-01, -5.70597351e-01,  1.28627408e+00,
#          1.91766910e-38],
#        [ 3.97418410e-01, -5.71661890e-01,  1.28867388e+00,
#          1.82547347e-38],
#        [ 4.00552601e-01, -5.72730422e-01,  1.29108262e+00,
#          1.52122789e-38],
#        ...,
#        [ 7.20216632e-01,  5.43281555e-01,  1.22469711e+00,
#          5.62393342e-39],
#        [ 7.22485065e-01,  5.43281555e-01,  1.22469711e+00,
#          5.71612905e-39],
#        [ 7.24753439e-01,  5.43281555e-01,  1.22469711e+00,
#          5.53173779e-39]])

# %%
color=np.round(((data[:,2]-data[:,2].min())/(data[:,2].max()-data[:,2].min())*255)).astype(int)
color
# Out:
# array([239, 240, 241, ..., 212, 212, 212])

# %%
z = data[:,2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 z = data[:,2]
#
# IndexError: index 2 is out of bounds for axis 1 with size 1

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Importing 3D plotting tools

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with three columns as X, Y, and Z
ax.scatter(data[:,0], data[:,1], data[:,2])



plt.ion()

plt.show()

plt.show(block=True)

# %%
# Generate random 3D data
np.random.seed(42)
n_points = 100
x = np.random.rand(n_points)
y = np.random.rand(n_points)
z = np.random.rand(n_points)

# Generate a random 1D color array
colors = np.random.rand(n_points)

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(x, y, z, c=colors, cmap='viridis')

# Add a color bar to show the mapping of values to colors
cbar = fig.colorbar(scatter, ax=ax, label='Color')

# Set labels for the axes
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.show()

# %%
import numpy as np

# Create a NumPy array with some NaN values
arr = np.array([[1.0, 2.0, np.nan],
                [4.0, np.nan, 6.0],
                [7.0, 8.0, 9.0]])

# Create a boolean mask where True corresponds to NaN values
nan_mask = np.isnan(arr)

# Use the mask to filter out NaN values
arr_no_nan = arr[~nan_mask]

print("Original array:")
print(arr)
print("\nArray without NaN values:")
print(arr_no_nan)
# Out:
# Original array:
# [[ 1.  2. nan]
#  [ 4. nan  6.]
#  [ 7.  8.  9.]]
#
# Array without NaN values:
# [1. 2. 4. 6. 7. 8. 9.]
